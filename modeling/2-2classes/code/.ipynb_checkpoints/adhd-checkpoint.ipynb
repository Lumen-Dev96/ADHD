# %%
from bokeh.plotting import figure, show, curdoc, output_notebook, layout
from bokeh.models import ColumnDataSource
from bokeh.io import push_notebook
import numpy as np
from datetime import datetime
from random import randint
import sys


# 初始化數據
data_length = 30

data_channels = 12

x = np.arange(data_length)

y_data = [np.zeros(data_length) for _ in range(data_channels)]

grapId = 0

# 初始化 Bokeh 的 ColumnDataSource
source = ColumnDataSource(data=dict(x=x, y=y_data[0]))
source2 = ColumnDataSource(data=dict(x=x, y=y_data[1]))

# 創建 Bokeh 的線型圖
plots = []
plot1 = figure(plot_height=300, title="Channel AX1", tools="crosshair,pan,reset,save,wheel_zoom")
line = plot1.line('x', 'y', source=source, line_width=2, line_alpha=0.8)

plot2 = figure(plot_height=300, title="Channel AY1", tools="crosshair,pan,reset,save,wheel_zoom")
line = plot2.line('x', 'y', source=source2, line_width=2, line_alpha=0.8)

plots.append(plot1)
plots.append(plot2)


grid = layout([[plot1], [plot2]])

# 將繪圖添加到文檔
#curdoc().add_root(layout([[plot1]], sizing_mode='scale_width'))


# 更新函數，每次呼叫時更新數據
def update(message):
    global x, y_data, grapId
    
    # 模擬獲取新數據，這裡使用 randint 生成隨機數
    new_data = np.random.randint(-10, 10, size=data_length)
    
    payload = message.payload.decode()
    data = json.loads(payload)
    mqData = np.array(data)
    channel1 = mqData[:, 0]
    channel2 = mqData[:, 1]

    print('mqttdata:', mqData.size)
    
    # 更新數據源的數據
    grapId += data_length
    source.stream(dict(x=np.arange(grapId, grapId + data_length), y=channel1))
    source2.stream(dict(x=np.arange(grapId, grapId + data_length), y=channel2))

    push_notebook()

# 在Jupyter Notebook中顯示
output_notebook()

show(grid, notebook_handle=True, notebook_url='localhost:8888')












import paho.mqtt.client as mqtt
import json

def on_connect(client, userdata, flags, rc):
    if rc == 0:
        print("Connected to MQTT broker")
    else:
        print("Failed to connect, return code %d\n", rc)

def on_message(client, userdata, message):
    update(message)
    print("Received data from esp32")
    #print("Received message on topic %s: %s" % (message.topic, message.payload.decode()))

# 连接MQTT代理
broker_address = "broker.emqx.io"
port = 1883
username = "test"
password = "123456"

client = mqtt.Client()
client.username_pw_set(username, password)
client.on_connect = on_connect
client.on_message = on_message


client.connect(broker_address, port)


# 订阅消息
topic = "Lumen"
client.subscribe(topic)

client.loop_forever()
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2657">Loading BokehJS ...</span>
#     </div>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/p9/cd90fl553wv30ydtk2k9spx40000gn/T/ipykernel_33937/3838038203.py in <module>
#      67 output_notebook()
#      68
# ---> 69 show(grid, notebook_handle=True, notebook_url='localhost:8888')
#      70
#      71
#
# /opt/anaconda3/envs/Python37/lib/python3.7/site-packages/bokeh/io/showing.py in show(obj, browser, new, notebook_handle, notebook_url, **kwargs)
#     142
#     143     if isinstance(obj, LayoutDOM):
# --> 144         return _show_with_state(obj, state, browser, new, notebook_handle=notebook_handle)
#     145
#     146     def is_application(obj: Any) -> TypeGuard[Application]:
#
# ...
