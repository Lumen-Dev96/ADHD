# %%
from bokeh.plotting import figure
from bokeh.models import ColumnDataSource
from bokeh.layouts import layout
from bokeh.io import push_notebook, show, output_notebook
import numpy as np
from tensorflow.keras.models import load_model
import sys
import pandas as pd
import paho.mqtt.client as mqtt
import json


# 初始化數據/設定
data_length = 30

data_channels = 12

x = np.arange(data_length)

y_data = [np.zeros(data_length) for _ in range(data_channels)]

grapId = 0

record_count = 0

rawData = []

max_data_count = 10

# 初始化 Bokeh 的 ColumnDataSource
source1 = ColumnDataSource(data={'x': x, 'y': y_data[0]})
source2 = ColumnDataSource(data={'x': x, 'y': y_data[1]})
source3 = ColumnDataSource(data={'x': x, 'y': y_data[2]})

source4 = ColumnDataSource(data={'x': x, 'y': y_data[3]})
source5 = ColumnDataSource(data={'x': x, 'y': y_data[4]})
source6 = ColumnDataSource(data={'x': x, 'y': y_data[5]})

source7 = ColumnDataSource(data={'x': x, 'y': y_data[6]})
source8 = ColumnDataSource(data={'x': x, 'y': y_data[7]})
source9 = ColumnDataSource(data={'x': x, 'y': y_data[8]})

source10 = ColumnDataSource(data={'x': x, 'y': y_data[9]})
source11 = ColumnDataSource(data={'x': x, 'y': y_data[10]})
source12 = ColumnDataSource(data={'x': x, 'y': y_data[11]})

source13 = ColumnDataSource(data={'x': np.arange(1), 'y': np.zeros(1)})



# 創建 Bokeh 的線型圖
plots = []
plot1 = figure(height=300, title="MPU1", tools="crosshair,pan,reset,save,wheel_zoom")
line_ax1 = plot1.line('x', 'y', source=source1, line_width=2, line_alpha=0.8, line_color='black', legend_label='AX1')
line_ay1 = plot1.line('x', 'y', source=source2, line_width=2, line_alpha=0.8, line_color='blue', legend_label='AY1')
line_az1 = plot1.line('x', 'y', source=source3, line_width=2, line_alpha=0.8, line_color='red', legend_label='AZ1')
line_gx1 = plot1.line('x', 'y', source=source4, line_width=2, line_alpha=0.8, line_color='green', legend_label='GX1')
line_gy1 = plot1.line('x', 'y', source=source5, line_width=2, line_alpha=0.8, line_color='yellow', legend_label='GY1')
line_gz1 = plot1.line('x', 'y', source=source6, line_width=2, line_alpha=0.8, line_color='pink', legend_label='GZ1')



# plot2 = figure(plot_height=300, title="Channel AY1", tools="crosshair,pan,reset,save,wheel_zoom")
# line = plot2.line('x', 'y', source=source2, line_width=2, line_alpha=0.8)

# plot3 = figure(plot_height=300, title="Channel AZ1", tools="crosshair,pan,reset,save,wheel_zoom")
# line = plot3.line('x', 'y', source=source3, line_width=2, line_alpha=0.8)

# plot4 = figure(plot_height=300, title="Channel GX1", tools="crosshair,pan,reset,save,wheel_zoom")
# line = plot4.line('x', 'y', source=source4, line_width=2, line_alpha=0.8)

# plot5 = figure(plot_height=300, title="Channel GY1", tools="crosshair,pan,reset,save,wheel_zoom")
# line = plot5.line('x', 'y', source=source5, line_width=2, line_alpha=0.8)

# plot6 = figure(plot_height=300, title="Channel GZ1", tools="crosshair,pan,reset,save,wheel_zoom")
# line = plot6.line('x', 'y', source=source6, line_width=2, line_alpha=0.8)

plot7 = figure(height=300, title="MPU2", tools="crosshair,pan,reset,save,wheel_zoom")
line_ax2 = plot7.line('x', 'y', source=source7, line_width=2, line_alpha=0.8, line_color='black', legend_label='AX2')
line_ay2 = plot7.line('x', 'y', source=source8, line_width=2, line_alpha=0.8, line_color='blue', legend_label='AY2')
line_az2 = plot7.line('x', 'y', source=source9, line_width=2, line_alpha=0.8, line_color='red', legend_label='AZ2')
line_gx2 = plot7.line('x', 'y', source=source10, line_width=2, line_alpha=0.8, line_color='green', legend_label='GX2')
line_gy2 = plot7.line('x', 'y', source=source11, line_width=2, line_alpha=0.8, line_color='yellow', legend_label='GY2')
line_gz2 = plot7.line('x', 'y', source=source12, line_width=2, line_alpha=0.8, line_color='pink', legend_label='GZ2')


# plot8 = figure(plot_height=300, title="Channel AY2", tools="crosshair,pan,reset,save,wheel_zoom")
# line = plot8.line('x', 'y', source=source8, line_width=2, line_alpha=0.8)

# plot9 = figure(plot_height=300, title="Channel AZ2", tools="crosshair,pan,reset,save,wheel_zoom")
# line = plot9.line('x', 'y', source=source9, line_width=2, line_alpha=0.8)

# plot10 = figure(plot_height=300, title="Channel GX2", tools="crosshair,pan,reset,save,wheel_zoom")
# line = plot10.line('x', 'y', source=source10, line_width=2, line_alpha=0.8)

# plot11 = figure(plot_height=300, title="Channel GY2", tools="crosshair,pan,reset,save,wheel_zoom")
# line = plot11.line('x', 'y', source=source11, line_width=2, line_alpha=0.8)

# plot12 = figure(plot_height=300, title="Channel GZ2", tools="crosshair,pan,reset,save,wheel_zoom")
# line = plot12.line('x', 'y', source=source12, line_width=2, line_alpha=0.8)

plot13 = figure(height=300, title="Predictions", tools="crosshair,pan,reset,save,wheel_zoom")
line = plot13.line('x', 'y', source=source13, line_width=2, line_alpha=0.8, line_color='black')


plots.append(plot1)
plots.append(plot7)
plots.append(plot13)
# plots.append(plot3)
# plots.append(plot4)
# plots.append(plot5)
# plots.append(plot6)
# plots.append(plot7)
# plots.append(plot8)
# plots.append(plot9)
# plots.append(plot10)
# plots.append(plot11)
# plots.append(plot12)


grid = layout(plots, sizing_mode='scale_width')

# 將繪圖添加到文檔
# curdoc().add_root(plot1)

# 在Jupyter Notebook中顯示
output_notebook()

# handle = show(plot1, notebook_handle=True)
show(grid, notebook_handle=True)
# push_notebook(handle=handle)


########### LOAD MODEL ###############
# 初始化一个空列表来保存预测结果
predictions = []
model_path = '/Users/luozijian/Code/ADHD/modeling/2-2classes/code/pb/test30_1.pb'
# model = tf.saved_model.load(model_path)
x_record = 1
model = load_model(model_path)
########### LOAD MODEL ###############



# 更新函數，每次呼叫時更新數據
def update(message):
    global x, y_data, grapId, x_record, rawData, record_count, max_data_count
    
    # 模擬獲取新數據，這裡使用 randint 生成隨機數
    new_data = np.random.randint(-10, 10, size=data_length)
    
    # 解碼 MQTT 數據
    payload = message.payload.decode()
    data = json.loads(payload)
    
    mqData = np.array(data[0])
    fifoData = np.array(data[1])
    
    channel1 = mqData[:, 0]
    channel2 = mqData[:, 1]
    channel3 = mqData[:, 2]
    channel4 = mqData[:, 3]
    channel5 = mqData[:, 4]
    channel6 = mqData[:, 5]
    channel7 = mqData[:, 6]
    channel8 = mqData[:, 7]
    channel9 = mqData[:, 8]
    channel10 = mqData[:, 9]
    channel11 = mqData[:, 10]
    channel12 = mqData[:, 11]

    rawData.append(mqData)
    record_count = record_count + 1
    
    # print('mqttdata:', mqData)

    # 使用模型进行预测
    # y_pred = model([fifoData])
    # TEST !!!!

    ranges = np.array([[1.7, 2], [6.7, 7], [-7, -6.6], [-4, 2], [-2, 2], [-8, -3], [0, 0.3], [9, 9.3], [-4.3, -4], [0, 5], [-2, 2], [-6, -4]])
    # 使用 numpy.random.uniform 生成具有不同範圍的數據
    dataForTest = np.column_stack([np.random.uniform(low=low, high=high, size=30) for low, high in ranges])
    print('-----------------')
    dataForTest = dataForTest[np.newaxis, ...]
    print('transforming test random data shape:', dataForTest.shape)

    fifoData = fifoData[np.newaxis, ...]
    print('transforming fifo data shape:', fifoData.shape)
    y_pred = model.predict(fifoData)

    predictions.append(y_pred[0])
    print('predictions:', predictions)
    print('------------------')

    # 将预测结果转换为 NumPy 数组
    predictionsNp = np.array(predictions)
    print('predictoinNp:', predictionsNp)
    print('------------------')
    print('predictions shape:', predictionsNp.shape)
    print(predictionsNp)
    # 提取预测类别的最大概率 >0.5 => 1, <0.5 => 0
    predicted_classes = predictionsNp[-1]
    print(predicted_classes)
    # 只會有一個結果, 值為0 或者 1
    print(predicted_classes[0])
    prediction_label = round(predicted_classes[0])
    print('predicted_classes', predicted_classes)
    print('prediction_label', prediction_label)
    x_record += 1
    source13.stream({'x':np.arange(x_record, x_record + 1), 'y':[prediction_label]})


    
    # 更新數據源的數據
    grapId += data_length
    source1.stream({'x':np.arange(grapId, grapId + data_length), 'y':channel1})
    source2.stream({'x':np.arange(grapId, grapId + data_length), 'y':channel2})
    source3.stream({'x':np.arange(grapId, grapId + data_length), 'y':channel3})
    source4.stream({'x':np.arange(grapId, grapId + data_length), 'y':channel4})
    source5.stream({'x':np.arange(grapId, grapId + data_length), 'y':channel5})
    source6.stream({'x':np.arange(grapId, grapId + data_length), 'y':channel6})
    source7.stream({'x':np.arange(grapId, grapId + data_length), 'y':channel7})
    source8.stream({'x':np.arange(grapId, grapId + data_length), 'y':channel8})
    source9.stream({'x':np.arange(grapId, grapId + data_length), 'y':channel9})
    source10.stream({'x':np.arange(grapId, grapId + data_length), 'y':channel10})
    source11.stream({'x':np.arange(grapId, grapId + data_length), 'y':channel11})
    source12.stream({'x':np.arange(grapId, grapId + data_length), 'y':channel12})
    
    #push_notebook(handle=handle)

    push_notebook()

    if record_count == max_data_count:
        exportCSV()











def exportCSV():
    global rawData
    csvData = np.concatenate(rawData, axis=0)
    ax1 = csvData[:, 0]
    ay1 = csvData[:, 1]
    az1 = csvData[:, 2]
    gx1 = csvData[:, 3]
    gy1 = csvData[:, 4]
    gz1 = csvData[:, 5]

    ax2 = csvData[:, 6] 
    ay2 = csvData[:, 7]
    az2 = csvData[:, 8]
    gx2 = csvData[:, 9]
    gy2 = csvData[:, 10]
    gz2 = csvData[:, 11]

    # dictionary of lists
    dict = {'Ax1': ax1, 'Ay1': ay1, 'Az1': az1, 'Gx1': gx1, 'Gy1': gy1, 'Gz1': gz1, 'Ax2': ax2, 'Ay2': ay2, 'Az2': az2, 'Gx2': gx2, 'Gy2': gy2, 'Gz2': gz2}
        
    df = pd.DataFrame(dict)
    df.to_csv('output.csv', index=False)


def on_connect(client, userdata, flags, rc):
    if rc == 0:
        print("Connected to MQTT broker")
    else:
        print("Failed to connect, return code %d\n", rc)

def on_message(client, userdata, message):
    update(message)
    print("Received data from esp32")
    #print("Received message on topic %s: %s" % (message.topic, message.payload.decode()))

# 连接MQTT代理
broker_address = "broker.emqx.io"
# broker_address = "broker.mqttdashboard.com"
# broker_address = "test.mosquitto.org"
port = 1883
username = "test1"
password = "1234567"

client = mqtt.Client()
client.username_pw_set(username, password)
client.on_connect = on_connect
client.on_message = on_message


client.connect(broker_address, port)


# 订阅消息
topic = "AD4"
client.subscribe(topic)

client.loop_forever()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="a4e96b88-5680-4c3c-b576-f90bf2840277">Loading BokehJS ...</span>
#     </div>
#   <div id="efc5f115-58ec-45c6-b49d-666abacfa1cc" data-root-id="p2602" style="display: contents;"></div>
# Connected to MQTT broker
# -----------------
# transforming test random data shape: (1, 30, 12)
# transforming fifo data shape: (1, 30, 12)
# 1/1 [==============================] - 0s 49ms/step
# predictions: [array([0.9730864], dtype=float32)]
# ------------------
# predictoinNp: [[0.9730864]]
# ------------------
# predictions shape: (1, 1)
# [[0.9730864]]
# [0.9730864]
# 0.9730864
# predicted_classes [0.9730864]
# prediction_label 1
# Received data from esp32
# -----------------
# transforming test random data shape: (1, 30, 12)
# transforming fifo data shape: (1, 30, 12)
# 1/1 [==============================] - 0s 19ms/step
# predictions: [array([0.9730864], dtype=float32), array([0.9730793], dtype=float32)]
# ------------------
# predictoinNp: [[0.9730864]
#  [0.9730793]]
# ------------------
# predictions shape: (2, 1)
# [[0.9730864]
#  [0.9730793]]
# [0.9730793]
# 0.9730793
# predicted_classes [0.9730793]
# prediction_label 1
# Received data from esp32
# -----------------
# transforming test random data shape: (1, 30, 12)
# transforming fifo data shape: (1, 30, 12)
# 1/1 [==============================] - 0s 16ms/step
# predictions: [array([0.9730864], dtype=float32), array([0.9730793], dtype=float32), array([0.97310513], dtype=float32)]
# ------------------
# predictoinNp: [[0.9730864 ]
#  [0.9730793 ]
#  [0.97310513]]
# ------------------
# predictions shape: (3, 1)
# [[0.9730864 ]
#  [0.9730793 ]
#  [0.97310513]]
# [0.97310513]
# 0.97310513
# predicted_classes [0.97310513]
# prediction_label 1
# Received data from esp32
# -----------------
# transforming test random data shape: (1, 30, 12)
# transforming fifo data shape: (1, 30, 12)
# 1/1 [==============================] - 0s 18ms/step
# predictions: [array([0.9730864], dtype=float32), array([0.9730793], dtype=float32), array([0.97310513], dtype=float32), array([0.97317004], dtype=float32)]
# ------------------
# predictoinNp: [[0.9730864 ]
#  [0.9730793 ]
#  [0.97310513]
#  [0.97317004]]
# ------------------
# predictions shape: (4, 1)
# [[0.9730864 ]
#  [0.9730793 ]
#  [0.97310513]
#  [0.97317004]]
# [0.97317004]
# 0.97317004
# predicted_classes [0.97317004]
# prediction_label 1
# Received data from esp32
# -----------------
# transforming test random data shape: (1, 30, 12)
# transforming fifo data shape: (1, 30, 12)
# 1/1 [==============================] - 0s 16ms/step
# predictions: [array([0.9730864], dtype=float32), array([0.9730793], dtype=float32), array([0.97310513], dtype=float32), array([0.97317004], dtype=float32), array([0.97317225], dtype=float32)]
# ------------------
# predictoinNp: [[0.9730864 ]
#  [0.9730793 ]
#  [0.97310513]
#  [0.97317004]
#  [0.97317225]]
# ------------------
# predictions shape: (5, 1)
# [[0.9730864 ]
#  [0.9730793 ]
#  [0.97310513]
#  [0.97317004]
#  [0.97317225]]
# [0.97317225]
# 0.97317225
# predicted_classes [0.97317225]
# prediction_label 1
# Received data from esp32
# -----------------
# transforming test random data shape: (1, 30, 12)
# transforming fifo data shape: (1, 30, 12)
# 1/1 [==============================] - 0s 17ms/step
# predictions: [array([0.9730864], dtype=float32), array([0.9730793], dtype=float32), array([0.97310513], dtype=float32), array([0.97317004], dtype=float32), array([0.97317225], dtype=float32), array([0.9730579], dtype=float32)]
# ------------------
# predictoinNp: [[0.9730864 ]
#  [0.9730793 ]
#  [0.97310513]
#  [0.97317004]
#  [0.97317225]
#  [0.9730579 ]]
# ------------------
# predictions shape: (6, 1)
# [[0.9730864 ]
#  [0.9730793 ]
#  [0.97310513]
#  [0.97317004]
#  [0.97317225]
#  [0.9730579 ]]
# [0.9730579]
# 0.9730579
# predicted_classes [0.9730579]
# prediction_label 1
# Received data from esp32
# -----------------
# transforming test random data shape: (1, 30, 12)
# transforming fifo data shape: (1, 30, 12)
# 1/1 [==============================] - 0s 17ms/step
# predictions: [array([0.9730864], dtype=float32), array([0.9730793], dtype=float32), array([0.97310513], dtype=float32), array([0.97317004], dtype=float32), array([0.97317225], dtype=float32), array([0.9730579], dtype=float32), array([0.9730419], dtype=float32)]
# ------------------
# predictoinNp: [[0.9730864 ]
#  [0.9730793 ]
#  [0.97310513]
#  [0.97317004]
#  [0.97317225]
#  [0.9730579 ]
#  [0.9730419 ]]
# ------------------
# predictions shape: (7, 1)
# [[0.9730864 ]
#  [0.9730793 ]
#  [0.97310513]
#  [0.97317004]
#  [0.97317225]
#  [0.9730579 ]
#  [0.9730419 ]]
# [0.9730419]
# 0.9730419
# predicted_classes [0.9730419]
# prediction_label 1
# Received data from esp32
# -----------------
# transforming test random data shape: (1, 30, 12)
# transforming fifo data shape: (1, 30, 12)
# 1/1 [==============================] - 0s 16ms/step
# predictions: [array([0.9730864], dtype=float32), array([0.9730793], dtype=float32), array([0.97310513], dtype=float32), array([0.97317004], dtype=float32), array([0.97317225], dtype=float32), array([0.9730579], dtype=float32), array([0.9730419], dtype=float32), array([0.97308064], dtype=float32)]
# ------------------
# predictoinNp: [[0.9730864 ]
#  [0.9730793 ]
#  [0.97310513]
#  [0.97317004]
#  [0.97317225]
#  [0.9730579 ]
#  [0.9730419 ]
#  [0.97308064]]
# ------------------
# predictions shape: (8, 1)
# [[0.9730864 ]
#  [0.9730793 ]
#  [0.97310513]
#  [0.97317004]
#  [0.97317225]
#  [0.9730579 ]
#  [0.9730419 ]
#  [0.97308064]]
# [0.97308064]
# 0.97308064
# predicted_classes [0.97308064]
# prediction_label 1
# Received data from esp32
# -----------------
# transforming test random data shape: (1, 30, 12)
# transforming fifo data shape: (1, 30, 12)
# 1/1 [==============================] - 0s 20ms/step
# predictions: [array([0.9730864], dtype=float32), array([0.9730793], dtype=float32), array([0.97310513], dtype=float32), array([0.97317004], dtype=float32), array([0.97317225], dtype=float32), array([0.9730579], dtype=float32), array([0.9730419], dtype=float32), array([0.97308064], dtype=float32), array([0.9730656], dtype=float32)]
# ------------------
# predictoinNp: [[0.9730864 ]
#  [0.9730793 ]
#  [0.97310513]
#  [0.97317004]
#  [0.97317225]
#  [0.9730579 ]
#  [0.9730419 ]
#  [0.97308064]
#  [0.9730656 ]]
# ------------------
# predictions shape: (9, 1)
# [[0.9730864 ]
#  [0.9730793 ]
#  [0.97310513]
#  [0.97317004]
#  [0.97317225]
#  [0.9730579 ]
#  [0.9730419 ]
#  [0.97308064]
#  [0.9730656 ]]
# [0.9730656]
# 0.9730656
# predicted_classes [0.9730656]
# prediction_label 1
# Received data from esp32
# -----------------
# transforming test random data shape: (1, 30, 12)
# transforming fifo data shape: (1, 30, 12)
# 1/1 [==============================] - 0s 18ms/step
# predictions: [array([0.9730864], dtype=float32), array([0.9730793], dtype=float32), array([0.97310513], dtype=float32), array([0.97317004], dtype=float32), array([0.97317225], dtype=float32), array([0.9730579], dtype=float32), array([0.9730419], dtype=float32), array([0.97308064], dtype=float32), array([0.9730656], dtype=float32), array([0.9730326], dtype=float32)]
# ------------------
# predictoinNp: [[0.9730864 ]
#  [0.9730793 ]
#  [0.97310513]
#  [0.97317004]
#  [0.97317225]
#  [0.9730579 ]
#  [0.9730419 ]
#  [0.97308064]
#  [0.9730656 ]
#  [0.9730326 ]]
# ------------------
# predictions shape: (10, 1)
# [[0.9730864 ]
#  [0.9730793 ]
#  [0.97310513]
#  [0.97317004]
#  [0.97317225]
#  [0.9730579 ]
#  [0.9730419 ]
#  [0.97308064]
#  [0.9730656 ]
#  [0.9730326 ]]
# [0.9730326]
# 0.9730326
# predicted_classes [0.9730326]
# prediction_label 1
# Received data from esp32
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 303
#     300 topic = "AD4"
#     301 client.subscribe(topic)
# --> 303 client.loop_forever()
#
# File /opt/anaconda3/envs/Python39/lib/python3.9/site-packages/paho/mqtt/client.py:1756, in Client.loop_forever(self, timeout, max_packets, retry_first_connection)
#    1754 rc = MQTT_ERR_SUCCESS
#    1755 while rc == MQTT_ERR_SUCCESS:
# -> 1756     rc = self._loop(timeout)
#    1757     # We don't need to worry about locking here, because we've
#    1758     # either called loop_forever() when in single threaded mode, or
#    1759     # in multi threaded mode when loop_stop() has been called and
#    1760     # so no other threads can access _out_packet or _messages.
#    1761     if (self._thread_terminate is True
#    1762         and len(self._out_packet) == 0
#    1763             and len(self._out_messages) == 0):
#
# File /opt/anaconda3/envs/Python39/lib/python3.9/site-packages/paho/mqtt/client.py:1164, in Client._loop(self, timeout)
#    1161     return MQTT_ERR_UNKNOWN
#    1163 if self._sock in socklist[0] or pending_bytes > 0:
# -> 1164     rc = self.loop_read()
#    1165     if rc or self._sock is None:
#    1166         return rc
#
# File /opt/anaconda3/envs/Python39/lib/python3.9/site-packages/paho/mqtt/client.py:1556, in Client.loop_read(self, max_packets)
#    1554 if self._sock is None:
#    1555     return MQTT_ERR_NO_CONN
# -> 1556 rc = self._packet_read()
#    1557 if rc > 0:
#    1558     return self._loop_rc_handle(rc)
#
# File /opt/anaconda3/envs/Python39/lib/python3.9/site-packages/paho/mqtt/client.py:2439, in Client._packet_read(self)
#    2437 # All data for this packet is read.
#    2438 self._in_packet['pos'] = 0
# -> 2439 rc = self._packet_handle()
#    2441 # Free data and reset values
#    2442 self._in_packet = {
#    2443     'command': 0,
#    2444     'have_remaining': 0,
#    (...)
#    2449     'to_process': 0,
#    2450     'pos': 0}
#
# File /opt/anaconda3/envs/Python39/lib/python3.9/site-packages/paho/mqtt/client.py:3033, in Client._packet_handle(self)
#    3031     return self._handle_pubackcomp("PUBCOMP")
#    3032 elif cmd == PUBLISH:
# -> 3033     return self._handle_publish()
#    3034 elif cmd == PUBREC:
#    3035     return self._handle_pubrec()
#
# File /opt/anaconda3/envs/Python39/lib/python3.9/site-packages/paho/mqtt/client.py:3327, in Client._handle_publish(self)
#    3325 message.timestamp = time_func()
#    3326 if message.qos == 0:
# -> 3327     self._handle_on_message(message)
#    3328     return MQTT_ERR_SUCCESS
#    3329 elif message.qos == 1:
#
# File /opt/anaconda3/envs/Python39/lib/python3.9/site-packages/paho/mqtt/client.py:3570, in Client._handle_on_message(self, message)
#    3568 with self._in_callback_mutex:
#    3569     try:
# -> 3570         on_message(self, self._userdata, message)
#    3571     except Exception as err:
#    3572         self._easy_log(
#    3573             MQTT_LOG_ERR, 'Caught exception in on_message: %s', err)
#
# Cell In[6], line 278, in on_message(client, userdata, message)
#     277 def on_message(client, userdata, message):
# --> 278     update(message)
#     279     print("Received data from esp32")
#
# Cell In[6], line 172, in update(message)
#     169 channel11 = mqData[:, 10]
#     170 channel12 = mqData[:, 11]
# --> 172 rawData.append(mqData)
#     173 record_count = record_count + 1
#     175 # print('mqttdata:', mqData)
#     176
#     177 # 使用模型进行预测
#     178 # y_pred = model([fifoData])
#     179 # TEST !!!!
#
# AttributeError: 'numpy.ndarray' object has no attribute 'append'
